# %%
import pandas as pd
import matplotlib as plt

# %%
df = pd.read_csv("../data/images_encoded.csv")

df.head()

label_counts = df.sum().drop("Filename")
print(label_counts)

label_counts.plot.barh()
# Out:
# baby          95
# bird         360
# car          319
# clouds      1095
# dog          448
# female      3227
# flower       761
# male        2979
# night        598
# people      6403
# portrait    3121
# river        120
# sea          173
# tree         525
# dtype: object
# <Axes: >
